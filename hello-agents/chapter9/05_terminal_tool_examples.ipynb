# %%
from hello_agents.tools import TerminalTool

terminal = TerminalTool(workspace="./project_notes")

# %%
# 第一步:查看项目根目录
print(terminal.run({"command": "ls -la"}))
"""
total 24
drwxr-xr-x  6 user  staff   192 Jan 19 16:00 .
drwxr-xr-x  5 user  staff   160 Jan 19 15:30 ..
-rw-r--r--  1 user  staff  1234 Jan 19 15:30 README.md
drwxr-xr-x  4 user  staff   128 Jan 19 15:30 src
drwxr-xr-x  3 user  staff    96 Jan 19 15:30 tests
-rw-r--r--  1 user  staff   456 Jan 19 15:30 requirements.txt
"""
# Out:
# total 24
# drwxrwxr-x 2 ubuntu ubuntu 4096 Dec  5 09:51 .
# drwxrwxr-x 6 ubuntu ubuntu 4096 Dec  7 08:46 ..
# -rw-rw-r-- 1 ubuntu ubuntu  342 Dec  5 07:13 note_20251205_071349_0.md
# -rw-rw-r-- 1 ubuntu ubuntu  437 Dec  5 09:51 note_20251205_095121_1.md
# -rw-rw-r-- 1 ubuntu ubuntu  419 Dec  5 09:51 note_20251205_095121_2.md
# -rw-rw-r-- 1 ubuntu ubuntu  813 Dec  5 09:51 notes_index.json
# '\ntotal 24\ndrwxr-xr-x  6 user  staff   192 Jan 19 16:00 .\ndrwxr-xr-x  5 user  staff   160 Jan 19 15:30 ..\n-rw-r--r--  1 user  staff  1234 Jan 19 15:30 README.md\ndrwxr-xr-x  4 user  staff   128 Jan 19 15:30 src\ndrwxr-xr-x  3 user  staff    96 Jan 19 15:30 tests\n-rw-r--r--  1 user  staff   456 Jan 19 15:30 requirements.txt\n'

# %%
# 第二步:查看源代码目录结构
# terminal.run({"command": "cd src"})
print(terminal.run({"command": "tree"}))

# 第三步:搜索特定模式
print(terminal.run({"command": "grep -r 'def process' ."}))
# Out:
# ⚠️ 命令返回码: 127
#
#
# [stderr]
# /bin/sh: 1: tree: not found
#
# ⚠️ 命令返回码: 1

# %%
print(terminal.run({"command": "cat notes_index.json"}))
# Out:
# {
#   "notes": [
#     {
#       "id": "note_20251205_071349_0",
#       "title": "重构项目 - 第一阶段",
#       "type": "task_state",
#       "tags": [
#         "refactoring",
#         "phase1"
#       ],
#       "created_at": "2025-12-05T07:13:49.819250"
#     },
#     {
#       "id": "note_20251205_095121_1",
#       "title": "重构项目 - 第一阶段",
#       "type": "task_state",
#       "tags": [
#         "refactoring",
#         "phase1"
#       ],
#       "created_at": "2025-12-05T09:51:21.695507"
#     },
#     {
#       "id": "note_20251205_095121_2",
#       "title": "依赖冲突问题",
#       "type": "blocker",
#       "tags": [
#         "dependency",
#         "urgent"
#       ],
#       "created_at": "2025-12-05T09:51:21.696072"
#     }
#   ],
#   "metadata": {
#     "created_at": "2025-12-05T07:13:49.818219",
#     "total_notes": 3
#   }
# }
