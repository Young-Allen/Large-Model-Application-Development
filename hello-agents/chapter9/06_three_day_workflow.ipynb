# %%
"""
CodebaseMaintainer 三天工作流演示

完整展示长程智能体在三天内的工作流程:
- 第一天: 探索代码库（Agent 自主探索）
- 第二天: 分析代码质量（Agent 自主分析）
- 第三天: 规划重构任务（Agent 自主规划）
- 一周后: 检查进度

"""

import os
# 配置嵌入模型（三选一）
# 方案一：TF-IDF（最简单，无需额外依赖）
# os.environ['EMBED_MODEL_TYPE'] = 'tfidf'
# os.environ['EMBED_MODEL_NAME'] = ''  # 重要：必须清空，否则会传递不兼容的参数
# 方案二：本地Transformer（需要: pip install sentence-transformers 和 HF token）
os.environ['EMBED_MODEL_TYPE'] = 'local'
os.environ['EMBED_MODEL_NAME'] = 'sentence-transformers/all-MiniLM-L6-v2'
# os.environ['HF_TOKEN'] = 'your_hf_token_here'  # 或使用 huggingface-cli login
# 方案三：通义千问（需要API key）
# os.environ['EMBED_MODEL_TYPE'] = 'dashscope'
# os.environ['EMBED_MODEL_NAME'] = 'text-embedding-v3'
# os.environ['EMBED_API_KEY'] = 'your_api_key_here'

from hello_agents import HelloAgentsLLM
from datetime import datetime
import json
import time

# 导入 CodebaseMaintainer
import sys
sys.path.append('.')
from codebase_maintainer import CodebaseMaintainer

# %%
def demonstrate_cross_session_continuity():
    """演示跨会话的连贯性"""
    print("\n" + "=" * 80)
    print("演示跨会话的连贯性")
    print("=" * 80 + "\n")

    # 第一次会话
    print("### 第一次会话 (session_1) ###")
    maintainer_1 = CodebaseMaintainer(
        project_name="demo_codebase",
        #实际使用的时候替换代码路径
        codebase_path="/Users/suntao/Documents/GitHub/hello-agents/code/chapter9/codebase",
        llm=HelloAgentsLLM()
    )

    # 创建一些笔记
    maintainer_1.create_note(
        title="代码质量问题",
        content="发现多处 TODO 注释需要实现，特别是数据验证和错误处理部分",
        note_type="blocker",
        tags=["quality", "urgent"]
    )

    stats_1 = maintainer_1.get_stats()
    print(f"会话1统计: {stats_1['activity']}\n")

    # 模拟会话结束
    time.sleep(1)

    # 第二次会话 (新的会话ID,但笔记被保留)
    print("### 第二次会话 (session_2) ###")
    maintainer_2 = CodebaseMaintainer(
        project_name="demo_codebase",  # 同一个项目
        #实际使用的时候替换代码路径
        codebase_path="/Users/suntao/Documents/GitHub/hello-agents/code/chapter9/codebase",
        llm=HelloAgentsLLM()
    )

    # 检索之前的笔记
    response = maintainer_2.run(
        "我们之前发现了什么代码质量问题？现在应该优先处理哪些？"
    )
    print(f"\n助手回答:\n{response[:300]}...\n")

    stats_2 = maintainer_2.get_stats()
    print(f"会话2统计: {stats_2['activity']}\n")

    # 展示笔记摘要
    summary = maintainer_2.note_tool.run({"action": "summary"})
    print("📊 跨会话笔记摘要:")
    print(json.dumps(summary, indent=2, ensure_ascii=False))


def demonstrate_tool_synergy():
    """演示三大工具的协同（Agentic 方式）
    
    在这个演示中：
    - 我们不再手动调用工具
    - 而是让 Agent 自主决定使用哪些工具
    - Agent 会根据任务自动协同使用多个工具
    """
    print("\n" + "=" * 80)
    print("演示三大工具的协同（Agent 自主协调）")
    print("=" * 80 + "\n")

    maintainer = CodebaseMaintainer(
        project_name="synergy_demo",
        #实际使用的时候替换代码路径
        codebase_path="/Users/suntao/Documents/GitHub/hello-agents/code/chapter9/codebase",
        llm=HelloAgentsLLM()
    )

    # Agent 自主分析并记录
    print("### Agent 自主分析代码库中的 TODO 项 ###")
    print("💡 提示：Agent 会自主决定：\n")
    print("   1. 使用 TerminalTool 查找 TODO")
    print("   2. 使用 NoteTool 记录发现")
    print("   3. 使用 MemoryTool 记住关键信息\n")
    
    response = maintainer.run(
        "请分析代码库中的所有 TODO 项，并将发现记录到笔记中。"
        "然后告诉我应该优先实现哪些功能。"
    )
    print(f"助手回答:\n{response[:500]}...\n")

    # 展示统计信息
    stats = maintainer.get_stats()
    print("📊 工具使用统计:")
    print(f"  - 工具调用次数: {stats['activity']['tool_calls']}")
    print(f"  - 执行的命令: {stats['activity']['commands_executed']}")
    print(f"  - 创建的笔记: {stats['activity']['notes_created']}")

# %%
"""主函数"""
print("=" * 80)
print("CodebaseMaintainer 三天工作流演示（Agentic 版本）")
print("=" * 80)

print("\n✨ 核心特性：Agent 自主决策")
print("💡 使用我们在 chapter9 创建的示例代码库")
print("📁 代码库路径: ./codebase")
print("📦 包含文件: data_processor.py, api_client.py, utils.py, models.py")
print("\n🔧 Agent 可用工具：")
print("   - TerminalTool: 执行 shell 命令")
print("   - NoteTool: 创建和管理笔记")
print("   - MemoryTool: 记忆管理")
print("\n⚡ Agent 会自主决定：")
print("   - 使用哪些工具")
print("   - 执行什么命令")
print("   - 如何组织信息\n")

# 初始化助手
maintainer = CodebaseMaintainer(
    project_name="demo_codebase",
    #实际使用的时候替换代码路径
    codebase_path="./codebase",
    llm=HelloAgentsLLM()
)
# Out:
# INFO:hello_agents.memory.manager:MemoryManager初始化完成，启用记忆类型: ['working']
# ================================================================================
# CodebaseMaintainer 三天工作流演示（Agentic 版本）
# ================================================================================
#
# ✨ 核心特性：Agent 自主决策
# 💡 使用我们在 chapter9 创建的示例代码库
# 📁 代码库路径: ./codebase
# 📦 包含文件: data_processor.py, api_client.py, utils.py, models.py
#
# 🔧 Agent 可用工具：
#    - TerminalTool: 执行 shell 命令
#    - NoteTool: 创建和管理笔记
#    - MemoryTool: 记忆管理
#
# ⚡ Agent 会自主决定：
#    - 使用哪些工具
#    - 执行什么命令
#    - 如何组织信息
#
# ✅ 工具 'terminal' 已注册。
# ✅ 工具 'note' 已注册。
# ✅ 工具 'memory' 已注册。
# ✅ 代码库维护助手已初始化: demo_codebase (Agentic Mode)
# 📁 工作目录: ./codebase
# 🆔 会话ID: session_20251208_081425
# 🔧 可用工具: terminal, note, memory

# %%
"""第一天: 探索代码库（Agentic 方式）

在这个阶段，我们只给 Agent 高层次的目标，
Agent 会自主决定：
- 使用哪些 shell 命令探索代码库
- 查看哪些文件
- 是否记录笔记
"""
print("\n" + "=" * 80)
print("第一天: 探索代码库（Agent 自主探索）")
print("=" * 80 + "\n")

# 1. 初步探索 - Agent 自主决定如何探索
print("### 1. 初步探索项目结构 ###")
print("💡 提示：Agent 会自主决定使用哪些命令（如 find, ls, cat）\n")
response = maintainer.explore()
print(f"\n助手总结:\n{response[:500]}...\n")

# 2. 深入分析某个模块 - Agent 自主决定分析方法
print("### 2. 分析数据处理模块 ###")
print("💡 提示：Agent 会自主决定如何分析这个文件\n")
response = maintainer.run("请查看 data_processor.py 文件，分析其代码设计")
print(f"\n助手总结:\n{response[:500]}...\n")

# 模拟时间流逝
time.sleep(1)
# Out:
# ================================================================================
# 第一天: 探索代码库（Agent 自主探索）
# ================================================================================
#
# ### 1. 初步探索项目结构 ###
# 💡 提示：Agent 会自主决定使用哪些命令（如 find, ls, cat）
#
#
# ================================================================================
# 👤 用户: 请探索 . 的代码结构，了解项目组织方式
# ================================================================================
#
# 🤖 Agent 正在思考并决定使用哪些工具...
#
# [{'type': 'function', 'function': {'name': 'terminal', 'description': '命令行工具 - 执行安全的文件系统、文本处理和代码执行命令（ls, cat, grep, head, tail等）', 'parameters': {'type': 'object', 'properties': {'command': {'type': 'string', 'description': "要执行的命令（白名单: cd, cut, df, dir, echo, file, head, ls, python, whereis...）\n示例: 'ls -la', 'cat file.txt', 'grep pattern *.py', 'head -n 20 data.csv'"}}, 'required': ['command']}}}, {'type': 'function', 'function': {'name': 'note', 'description': '笔记工具 - 创建、读取、更新、删除结构化笔记，支持任务状态、结论、阻塞项等类型', 'parameters': {'type': 'object', 'properties': {'action': {'type': 'string', 'description': '操作类型: create(创建), read(读取), update(更新), delete(删除), list(列表), search(搜索), summary(摘要)'}, 'title': {'type': 'string', 'description': '笔记标题（create/update时必需）'}, 'content': {'type': 'string', 'description': '笔记内容（create/update时必需）'}, 'note_type': {'type': 'string', 'description': '笔记类型: task_state(任务状态), conclusion(结论), blocker(阻塞项), action(行动计划), reference(参考), general(通用)', 'default': 'general'}, 'tags': {'type': 'string', 'description': '标签列表（可选）'}, 'note_id': {'type': 'string', 'description': '笔记ID（read/update/delete时必需）'}, 'query': {'type': 'string', 'description': '搜索关键词（search时必需）'}, 'limit': {'type': 'integer', 'description': '返回结果数量限制（默认10）', 'default': 10}}, 'required': ['action']}}}, {'type': 'function', 'function': {'name': 'memory', 'description': '记忆工具 - 可以存储和检索对话历史、知识和经验', 'parameters': {'type': 'object', 'properties': {'action': {'type': 'string', 'description': '要执行的操作：add(添加记忆), search(搜索记忆), summary(获取摘要), stats(获取统计), update(更新记忆), remove(删除记忆), forget(遗忘记忆), consolidate(整合记忆), clear_all(清空所有记忆)'}, 'content': {'type': 'string', 'description': '记忆内容（add/update时可用；感知记忆可作描述）'}, 'query': {'type': 'string', 'description': '搜索查询（search时可用）'}, 'memory_type': {'type': 'string', 'description': '记忆类型：working, episodic, semantic, perceptual（默认：working）', 'default': 'working'}, 'importance': {'type': 'number', 'description': '重要性分数，0.0-1.0（add/update时可用）'}, 'limit': {'type': 'integer', 'description': '搜索结果数量限制（默认：5）', 'default': 5}, 'memory_id': {'type': 'string', 'description': '目标记忆ID（update/remove时必需）'}, 'file_path': {'type': 'string', 'description': '感知记忆：本地文件路径（image/audio）'}, 'modality': {'type': 'string', 'description': '感知记忆模态：text/image/audio（不传则按扩展名推断）'}, 'strategy': {'type': 'string', 'description': '遗忘策略：importance_based/time_based/capacity_based（forget时可用）', 'default': 'importance_based'}, 'threshold': {'type': 'number', 'description': '遗忘阈值（forget时可用，默认0.1）', 'default': 0.1}, 'max_age_days': {'type': 'integer', 'description': '最大保留天数（forget策略为time_based时可用）', 'default': 30}, 'from_type': {'type': 'string', 'description': '整合来源类型（consolidate时可用，默认working）', 'default': 'working'}, 'to_type': {'type': 'string', 'description': '整合目标类型（consolidate时可用，默认episodic）', 'default': 'episodic'}, 'importance_threshold': {'type': 'number', 'description': '整合重要性阈值（默认0.7）', 'default': 0.7}}, 'required': ['action']}}}]
#
# 🤖 助手: 1. 结论
#    - 代码库由四个主要模块组成：**API Client Module** (`api_client.py`)，**Data Processing Module** (`data_processor.py`)，**Data Models Module** (`models.py`)，以及**Utility Functions Module** (`utils.py`)。这些模块分别负责API交互、数据处理、数据模型定义和通用工具函数。
#
# 2. 依据
#    - `api_client.py`: 包含用于API交互的`APIClient`类，支持GET、POST、PUT和DELETE请求。
#    - `data_processor.py`: 使用Pandas处理和转换数据，提供数据清洗、转换和导出等功能。
#    - `models.py`: 定义了`User`、`Product`、`Order`和`Transaction`等数据模型，使用Python dataclasses。
#    - `utils.py`: 提供配置文件加载、目录管理和数据格式化等工具函数。
#
# 3. 风险与假设
#    - 假设这些模块的功能实现和使用符合项目需求，且没有隐藏的依赖或外部配置问题。
#
# 4. 下一步行动建议
#    - 进一步检查每个模块的详细实现，特别是TODO标记的部分，以确保功能的完整性和鲁棒性。
#    - 考虑添加单元测试以验证各模块的功能和集成正确性。
#    - 检查是否需要补充文档以提高代码的可维护性和可读性。
#
# ================================================================================
#
#
# 助手总结:
# 1. 结论
#    - 代码库由四个主要模块组成：**API Client Module** (`api_client.py`)，**Data Processing Module** (`data_processor.py`)，**Data Models Module** (`models.py`)，以及**Utility Functions Module** (`utils.py`)。这些模块分别负责API交互、数据处理、数据模型定义和通用工具函数。
#
# 2. 依据
#    - `api_client.py`: 包含用于API交互的`APIClient`类，支持GET、POST、PUT和DELETE请求。
#    - `data_processor.py`: 使用Pandas处理和转换数据，提供数据清洗、转换和导出等功能。
#    - `models.py`: 定义了`User`、`Product`、`Order`和`Transaction`等数据模型，使用Python dataclasses。
#    - `utils.py`: 提供配置文件加载、目录管理和数据格式化等工具函数。
#
# 3. 风险...
#
# ### 2. 分析数据处理模块 ###
# 💡 提示：Agent 会自主决定如何分析这个文件
#
#
# ================================================================================
# 👤 用户: 请查看 data_processor.py 文件，分析其代码设计
# ================================================================================
#
# 🤖 Agent 正在思考并决定使用哪些工具...
#
# [{'type': 'function', 'function': {'name': 'terminal', 'description': '命令行工具 - 执行安全的文件系统、文本处理和代码执行命令（ls, cat, grep, head, tail等）', 'parameters': {'type': 'object', 'properties': {'command': {'type': 'string', 'description': "要执行的命令（白名单: cd, cut, df, dir, echo, file, head, ls, python, whereis...）\n示例: 'ls -la', 'cat file.txt', 'grep pattern *.py', 'head -n 20 data.csv'"}}, 'required': ['command']}}}, {'type': 'function', 'function': {'name': 'note', 'description': '笔记工具 - 创建、读取、更新、删除结构化笔记，支持任务状态、结论、阻塞项等类型', 'parameters': {'type': 'object', 'properties': {'action': {'type': 'string', 'description': '操作类型: create(创建), read(读取), update(更新), delete(删除), list(列表), search(搜索), summary(摘要)'}, 'title': {'type': 'string', 'description': '笔记标题（create/update时必需）'}, 'content': {'type': 'string', 'description': '笔记内容（create/update时必需）'}, 'note_type': {'type': 'string', 'description': '笔记类型: task_state(任务状态), conclusion(结论), blocker(阻塞项), action(行动计划), reference(参考), general(通用)', 'default': 'general'}, 'tags': {'type': 'string', 'description': '标签列表（可选）'}, 'note_id': {'type': 'string', 'description': '笔记ID（read/update/delete时必需）'}, 'query': {'type': 'string', 'description': '搜索关键词（search时必需）'}, 'limit': {'type': 'integer', 'description': '返回结果数量限制（默认10）', 'default': 10}}, 'required': ['action']}}}, {'type': 'function', 'function': {'name': 'memory', 'description': '记忆工具 - 可以存储和检索对话历史、知识和经验', 'parameters': {'type': 'object', 'properties': {'action': {'type': 'string', 'description': '要执行的操作：add(添加记忆), search(搜索记忆), summary(获取摘要), stats(获取统计), update(更新记忆), remove(删除记忆), forget(遗忘记忆), consolidate(整合记忆), clear_all(清空所有记忆)'}, 'content': {'type': 'string', 'description': '记忆内容（add/update时可用；感知记忆可作描述）'}, 'query': {'type': 'string', 'description': '搜索查询（search时可用）'}, 'memory_type': {'type': 'string', 'description': '记忆类型：working, episodic, semantic, perceptual（默认：working）', 'default': 'working'}, 'importance': {'type': 'number', 'description': '重要性分数，0.0-1.0（add/update时可用）'}, 'limit': {'type': 'integer', 'description': '搜索结果数量限制（默认：5）', 'default': 5}, 'memory_id': {'type': 'string', 'description': '目标记忆ID（update/remove时必需）'}, 'file_path': {'type': 'string', 'description': '感知记忆：本地文件路径（image/audio）'}, 'modality': {'type': 'string', 'description': '感知记忆模态：text/image/audio（不传则按扩展名推断）'}, 'strategy': {'type': 'string', 'description': '遗忘策略：importance_based/time_based/capacity_based（forget时可用）', 'default': 'importance_based'}, 'threshold': {'type': 'number', 'description': '遗忘阈值（forget时可用，默认0.1）', 'default': 0.1}, 'max_age_days': {'type': 'integer', 'description': '最大保留天数（forget策略为time_based时可用）', 'default': 30}, 'from_type': {'type': 'string', 'description': '整合来源类型（consolidate时可用，默认working）', 'default': 'working'}, 'to_type': {'type': 'string', 'description': '整合目标类型（consolidate时可用，默认episodic）', 'default': 'episodic'}, 'importance_threshold': {'type': 'number', 'description': '整合重要性阈值（默认0.7）', 'default': 0.7}}, 'required': ['action']}}}]
#
# 🤖 助手: 1. 结论
#    - `data_processor.py`文件设计了一个数据处理模块，主要功能包括数据清理、转换、聚合和导出，使用Pandas库进行数据操作。
#
# 2. 依据
#    - **函数设计**:
#      - `process_data`: 负责将原始数据列表转换为DataFrame，并调用数据清理和转换函数。
#      - `clean_data`: 实现基本的数据清理（如删除空值和重复项）。
#      - `transform_data`: 进行数据类型转换（将`date`字段转换为日期类型）。
#      - `aggregate_data`: 提供基于给定字段的聚合功能，支持`sum`, `mean`, `count`等操作。
#      - `export_data`: 将处理后的DataFrame导出为CSV文件。
#
# 3. 风险与假设
#    - **风险**:
#      - 当前实现的清理和转换逻辑较为简单，可能无法处理复杂的异常数据或转换需求。
#      - 缺乏数据验证逻辑，可能导致数据质量问题。
#    - **假设**:
#      - 假设输入数据格式正确，并且所有字段在数据中都存在。
#
# 4. 下一步行动建议
#    - 增强数据验证和清理逻辑，以处理更多异常情况。
#    - 扩展数据转换功能，支持更多的字段和格式。
#    - 实现更多的数据导出格式（如Excel、JSON等）。
#    - 考虑添加日志记录功能以跟踪数据处理过程中的问题。
#    - 增加单元测试以验证数据处理的正确性和鲁棒性。
#
# ================================================================================
#
#
# 助手总结:
# 1. 结论
#    - `data_processor.py`文件设计了一个数据处理模块，主要功能包括数据清理、转换、聚合和导出，使用Pandas库进行数据操作。
#
# 2. 依据
#    - **函数设计**:
#      - `process_data`: 负责将原始数据列表转换为DataFrame，并调用数据清理和转换函数。
#      - `clean_data`: 实现基本的数据清理（如删除空值和重复项）。
#      - `transform_data`: 进行数据类型转换（将`date`字段转换为日期类型）。
#      - `aggregate_data`: 提供基于给定字段的聚合功能，支持`sum`, `mean`, `count`等操作。
#      - `export_data`: 将处理后的DataFrame导出为CSV文件。
#
# 3. 风险与假设
#    - **风险**:
#      - 当前实现的清理和转换逻辑较为简单，可能无法处理复杂的异常数据或转换需求。
#      - 缺乏数据验证逻辑，可能导致数据质量问题。
#    - **假设**:
#      - 假设输入数据格式正确，并且...

# %%
"""第二天: 分析代码质量（Agentic 方式）

Agent 会自主决定：
- 使用什么方法分析代码质量（grep TODO? 统计行数? 检查复杂度?）
- 是否需要创建笔记记录问题
- 如何组织分析结果
"""
print("\n" + "=" * 80)
print("第二天: 分析代码质量（Agent 自主分析）")
print("=" * 80 + "\n")

# 1. 整体质量分析 - Agent 自主决定分析方法
print("### 1. 分析代码质量 ###")
print("💡 提示：Agent 会自主决定如何分析（如 grep TODO, wc -l, 复杂度分析）\n")
response = maintainer.analyze()
print(f"\n助手总结:\n{response[:500]}...\n")

# 2. 查看具体问题 - Agent 自主深入分析
print("### 2. 分析 API 客户端代码 ###")
print("💡 提示：Agent 会自主决定如何分析这个文件的质量\n")
response = maintainer.run(
    "请分析 api_client.py 的代码质量，特别是错误处理部分，给出改进建议"
)
print(f"\n助手总结:\n{response[:500]}...\n")

# 模拟时间流逝
time.sleep(1)
# Out:
# ================================================================================
# 第二天: 分析代码质量（Agent 自主分析）
# ================================================================================
#
# ### 1. 分析代码质量 ###
# 💡 提示：Agent 会自主决定如何分析（如 grep TODO, wc -l, 复杂度分析）
#
#
# ================================================================================
# 👤 用户: 请分析代码质量
# ================================================================================
#
# 🤖 Agent 正在思考并决定使用哪些工具...
#
# [{'type': 'function', 'function': {'name': 'terminal', 'description': '命令行工具 - 执行安全的文件系统、文本处理和代码执行命令（ls, cat, grep, head, tail等）', 'parameters': {'type': 'object', 'properties': {'command': {'type': 'string', 'description': "要执行的命令（白名单: cd, cut, df, dir, echo, file, head, ls, python, whereis...）\n示例: 'ls -la', 'cat file.txt', 'grep pattern *.py', 'head -n 20 data.csv'"}}, 'required': ['command']}}}, {'type': 'function', 'function': {'name': 'note', 'description': '笔记工具 - 创建、读取、更新、删除结构化笔记，支持任务状态、结论、阻塞项等类型', 'parameters': {'type': 'object', 'properties': {'action': {'type': 'string', 'description': '操作类型: create(创建), read(读取), update(更新), delete(删除), list(列表), search(搜索), summary(摘要)'}, 'title': {'type': 'string', 'description': '笔记标题（create/update时必需）'}, 'content': {'type': 'string', 'description': '笔记内容（create/update时必需）'}, 'note_type': {'type': 'string', 'description': '笔记类型: task_state(任务状态), conclusion(结论), blocker(阻塞项), action(行动计划), reference(参考), general(通用)', 'default': 'general'}, 'tags': {'type': 'string', 'description': '标签列表（可选）'}, 'note_id': {'type': 'string', 'description': '笔记ID（read/update/delete时必需）'}, 'query': {'type': 'string', 'description': '搜索关键词（search时必需）'}, 'limit': {'type': 'integer', 'description': '返回结果数量限制（默认10）', 'default': 10}}, 'required': ['action']}}}, {'type': 'function', 'function': {'name': 'memory', 'description': '记忆工具 - 可以存储和检索对话历史、知识和经验', 'parameters': {'type': 'object', 'properties': {'action': {'type': 'string', 'description': '要执行的操作：add(添加记忆), search(搜索记忆), summary(获取摘要), stats(获取统计), update(更新记忆), remove(删除记忆), forget(遗忘记忆), consolidate(整合记忆), clear_all(清空所有记忆)'}, 'content': {'type': 'string', 'description': '记忆内容（add/update时可用；感知记忆可作描述）'}, 'query': {'type': 'string', 'description': '搜索查询（search时可用）'}, 'memory_type': {'type': 'string', 'description': '记忆类型：working, episodic, semantic, perceptual（默认：working）', 'default': 'working'}, 'importance': {'type': 'number', 'description': '重要性分数，0.0-1.0（add/update时可用）'}, 'limit': {'type': 'integer', 'description': '搜索结果数量限制（默认：5）', 'default': 5}, 'memory_id': {'type': 'string', 'description': '目标记忆ID（update/remove时必需）'}, 'file_path': {'type': 'string', 'description': '感知记忆：本地文件路径（image/audio）'}, 'modality': {'type': 'string', 'description': '感知记忆模态：text/image/audio（不传则按扩展名推断）'}, 'strategy': {'type': 'string', 'description': '遗忘策略：importance_based/time_based/capacity_based（forget时可用）', 'default': 'importance_based'}, 'threshold': {'type': 'number', 'description': '遗忘阈值（forget时可用，默认0.1）', 'default': 0.1}, 'max_age_days': {'type': 'integer', 'description': '最大保留天数（forget策略为time_based时可用）', 'default': 30}, 'from_type': {'type': 'string', 'description': '整合来源类型（consolidate时可用，默认working）', 'default': 'working'}, 'to_type': {'type': 'string', 'description': '整合目标类型（consolidate时可用，默认episodic）', 'default': 'episodic'}, 'importance_threshold': {'type': 'number', 'description': '整合重要性阈值（默认0.7）', 'default': 0.7}}, 'required': ['action']}}}]
#
# 🤖 助手: 1. 结论
#    - **代码质量存在改进空间**，特别是在数据验证、错误处理和功能完善方面。多个文件中存在许多`TODO`标记，表明功能或完善性较弱。
#
# 2. 依据
#    - `data_processor.py`:
#      - 存在多个`TODO`标记：需要添加数据验证逻辑、实现更复杂的清理逻辑、添加更多转换规则和支持更多输出格式。
#    - `api_client.py`:
#      - 需要增加重试逻辑、错误处理和确认机制。
#    - `utils.py`:
#      - 需要支持多种配置文件格式和优化格式化逻辑。
#    - `models.py`:
#      - 需要添加用户验证方法、考虑折扣和税费、以及退款功能。
#    - 未能执行`pylint`命令获取详细的代码质量分析，因为不在允许的命令列表中。
#
# 3. 风险与假设
#    - **风险**:
#      - 由于多个`TODO`未完成，可能导致功能不完整或处理不当。
#      - 缺乏详细的静态代码分析结果，可能存在潜在的代码风格和质量问题。
#    - **假设**:
#      - 假设`TODO`标记的内容是当前代码库的主要改进方向。
#
# 4. 下一步行动建议
#    - 优先处理`TODO`标记的任务，以提升功能完善度和代码质量。
#    - 执行代码审查和静态分析，特别是使用工具如`pylint`来发现潜在问题。
#    - 引入单元测试和集成测试以确保代码的正确性和健壮性。
#    - 定期进行代码重构和优化以提高可维护性和可读性。
#
# ================================================================================
#
#
# 助手总结:
# 1. 结论
#    - **代码质量存在改进空间**，特别是在数据验证、错误处理和功能完善方面。多个文件中存在许多`TODO`标记，表明功能或完善性较弱。
#
# 2. 依据
#    - `data_processor.py`:
#      - 存在多个`TODO`标记：需要添加数据验证逻辑、实现更复杂的清理逻辑、添加更多转换规则和支持更多输出格式。
#    - `api_client.py`:
#      - 需要增加重试逻辑、错误处理和确认机制。
#    - `utils.py`:
#      - 需要支持多种配置文件格式和优化格式化逻辑。
#    - `models.py`:
#      - 需要添加用户验证方法、考虑折扣和税费、以及退款功能。
#    - 未能执行`pylint`命令获取详细的代码质量分析，因为不在允许的命令列表中。
#
# 3. 风险与假设
#    - **风险**:
#      - 由于多个`TODO`未完成，可能导致功能不完整或处理不当。
#      - 缺乏详细的静态代码分析结果，可能存在潜在的代码风格和质量问题。
#    - **假设**:
#      - 假设`TODO`标记的内容是当前代码...
#
# ### 2. 分析 API 客户端代码 ###
# 💡 提示：Agent 会自主决定如何分析这个文件的质量
#
#
# ================================================================================
# 👤 用户: 请分析 api_client.py 的代码质量，特别是错误处理部分，给出改进建议
# ================================================================================
#
# 🤖 Agent 正在思考并决定使用哪些工具...
#
# [{'type': 'function', 'function': {'name': 'terminal', 'description': '命令行工具 - 执行安全的文件系统、文本处理和代码执行命令（ls, cat, grep, head, tail等）', 'parameters': {'type': 'object', 'properties': {'command': {'type': 'string', 'description': "要执行的命令（白名单: cd, cut, df, dir, echo, file, head, ls, python, whereis...）\n示例: 'ls -la', 'cat file.txt', 'grep pattern *.py', 'head -n 20 data.csv'"}}, 'required': ['command']}}}, {'type': 'function', 'function': {'name': 'note', 'description': '笔记工具 - 创建、读取、更新、删除结构化笔记，支持任务状态、结论、阻塞项等类型', 'parameters': {'type': 'object', 'properties': {'action': {'type': 'string', 'description': '操作类型: create(创建), read(读取), update(更新), delete(删除), list(列表), search(搜索), summary(摘要)'}, 'title': {'type': 'string', 'description': '笔记标题（create/update时必需）'}, 'content': {'type': 'string', 'description': '笔记内容（create/update时必需）'}, 'note_type': {'type': 'string', 'description': '笔记类型: task_state(任务状态), conclusion(结论), blocker(阻塞项), action(行动计划), reference(参考), general(通用)', 'default': 'general'}, 'tags': {'type': 'string', 'description': '标签列表（可选）'}, 'note_id': {'type': 'string', 'description': '笔记ID（read/update/delete时必需）'}, 'query': {'type': 'string', 'description': '搜索关键词（search时必需）'}, 'limit': {'type': 'integer', 'description': '返回结果数量限制（默认10）', 'default': 10}}, 'required': ['action']}}}, {'type': 'function', 'function': {'name': 'memory', 'description': '记忆工具 - 可以存储和检索对话历史、知识和经验', 'parameters': {'type': 'object', 'properties': {'action': {'type': 'string', 'description': '要执行的操作：add(添加记忆), search(搜索记忆), summary(获取摘要), stats(获取统计), update(更新记忆), remove(删除记忆), forget(遗忘记忆), consolidate(整合记忆), clear_all(清空所有记忆)'}, 'content': {'type': 'string', 'description': '记忆内容（add/update时可用；感知记忆可作描述）'}, 'query': {'type': 'string', 'description': '搜索查询（search时可用）'}, 'memory_type': {'type': 'string', 'description': '记忆类型：working, episodic, semantic, perceptual（默认：working）', 'default': 'working'}, 'importance': {'type': 'number', 'description': '重要性分数，0.0-1.0（add/update时可用）'}, 'limit': {'type': 'integer', 'description': '搜索结果数量限制（默认：5）', 'default': 5}, 'memory_id': {'type': 'string', 'description': '目标记忆ID（update/remove时必需）'}, 'file_path': {'type': 'string', 'description': '感知记忆：本地文件路径（image/audio）'}, 'modality': {'type': 'string', 'description': '感知记忆模态：text/image/audio（不传则按扩展名推断）'}, 'strategy': {'type': 'string', 'description': '遗忘策略：importance_based/time_based/capacity_based（forget时可用）', 'default': 'importance_based'}, 'threshold': {'type': 'number', 'description': '遗忘阈值（forget时可用，默认0.1）', 'default': 0.1}, 'max_age_days': {'type': 'integer', 'description': '最大保留天数（forget策略为time_based时可用）', 'default': 30}, 'from_type': {'type': 'string', 'description': '整合来源类型（consolidate时可用，默认working）', 'default': 'working'}, 'to_type': {'type': 'string', 'description': '整合目标类型（consolidate时可用，默认episodic）', 'default': 'episodic'}, 'importance_threshold': {'type': 'number', 'description': '整合重要性阈值（默认0.7）', 'default': 0.7}}, 'required': ['action']}}}]
#
# 🤖 助手: 1. 结论
#    - `api_client.py`的代码质量在错误处理方面需要显著改进。目前的实现缺乏对网络请求错误的详细处理和响应，可能导致未预期的异常抛出。
#
# 2. 依据
#    - **缺乏重试逻辑**: `get`方法中的`TODO`标记指出需要添加重试逻辑，以应对临时性网络问题。
#    - **错误处理不足**: `post`方法存在`TODO`标记，表示需要添加错误处理。目前的实现仅依赖`raise_for_status`，未提供详细的错误信息或日志记录。
#    - **确认机制缺失**: `delete`方法的`TODO`标记指出需要添加确认机制，避免误删除操作。
#    - **统一的异常处理**: 目前各方法未实现统一的异常捕获和处理策略，例如捕获`requests.exceptions.RequestException`以提供更具体的错误信息。
#
# 3. 风险与假设
#    - **风险**:
#      - 缺乏完善的错误处理可能导致在API请求失败时，应用程序无法提供用户友好的错误信息。
#      - 未添加重试逻辑可能影响应用的鲁棒性和用户体验。
#    - **假设**:
#      - 假设所有API响应均为JSON格式且不需要其他格式的解析。
#
# 4. 下一步行动建议
#    - **添加重试逻辑**: 使用库如`tenacity`以实现网络请求的重试机制。
#    - **改进错误处理**: 在每个请求方法中，添加对`requests.exceptions`的捕获，并记录详细的错误信息。可以考虑引入日志记录来跟踪请求失败的原因。
#    - **实现确认机制**: 在`delete`方法中实现双重确认机制，或提供可选参数以确认删除操作。
#    - **统一异常管理**: 创建一个私有方法来处理所有API请求中的异常，确保一致性和可维护性。
#
# ================================================================================
#
#
# 助手总结:
# 1. 结论
#    - `api_client.py`的代码质量在错误处理方面需要显著改进。目前的实现缺乏对网络请求错误的详细处理和响应，可能导致未预期的异常抛出。
#
# 2. 依据
#    - **缺乏重试逻辑**: `get`方法中的`TODO`标记指出需要添加重试逻辑，以应对临时性网络问题。
#    - **错误处理不足**: `post`方法存在`TODO`标记，表示需要添加错误处理。目前的实现仅依赖`raise_for_status`，未提供详细的错误信息或日志记录。
#    - **确认机制缺失**: `delete`方法的`TODO`标记指出需要添加确认机制，避免误删除操作。
#    - **统一的异常处理**: 目前各方法未实现统一的异常捕获和处理策略，例如捕获`requests.exceptions.RequestException`以提供更具体的错误信息。
#
# 3. 风险与假设
#    - **风险**:
#      - 缺乏完善的错误处理可能导致在API请求失败时，应用程序无法提供用户友好的错误信息。
#      - 未添加重试逻辑可能影响应用的鲁棒性和用户体验。
#    - **假设*...

# %%
"""第三天: 规划重构任务（Agentic 方式）

Agent 会自主决定：
- 回顾哪些历史笔记
- 如何组织任务规划
- 是否需要创建新的笔记
- 如何安排优先级
"""
print("\n" + "=" * 80)
print("第三天: 规划重构任务（Agent 自主规划）")
print("=" * 80 + "\n")

# 1. 回顾进度 - Agent 自主查看历史笔记并规划
print("### 1. 回顾当前进度并规划下一步 ###")
print("💡 提示：Agent 会自主查看历史笔记，分析当前进度，并制定计划\n")
response = maintainer.plan_next_steps()
print(f"\n助手总结:\n{response[:500]}...\n")

# 2. 询问 Agent 创建详细计划（Agent 会自主决定是否使用 NoteTool）
print("### 2. 让 Agent 创建详细的重构计划 ###")
print("💡 提示：Agent 会自主决定如何创建和组织重构计划\n")
response = maintainer.run(
    "请基于我们的分析，创建一个详细的本周重构计划。"
    "计划应该包括：目标、具体任务清单、时间安排和风险。"
    "请使用 NoteTool 创建一个 task_state 类型的笔记来记录这个计划。"
)
print(f"\n助手总结:\n{response[:500]}...\n")

# 模拟时间流逝
time.sleep(1)
# Out:
# ================================================================================
# 第三天: 规划重构任务（Agent 自主规划）
# ================================================================================
#
# ### 1. 回顾当前进度并规划下一步 ###
# 💡 提示：Agent 会自主查看历史笔记，分析当前进度，并制定计划
#
#
# ================================================================================
# 👤 用户: 根据我们之前的分析和当前进度，规划下一步任务
# ================================================================================
#
# 🤖 Agent 正在思考并决定使用哪些工具...
#
# [{'type': 'function', 'function': {'name': 'terminal', 'description': '命令行工具 - 执行安全的文件系统、文本处理和代码执行命令（ls, cat, grep, head, tail等）', 'parameters': {'type': 'object', 'properties': {'command': {'type': 'string', 'description': "要执行的命令（白名单: cd, cut, df, dir, echo, file, head, ls, python, whereis...）\n示例: 'ls -la', 'cat file.txt', 'grep pattern *.py', 'head -n 20 data.csv'"}}, 'required': ['command']}}}, {'type': 'function', 'function': {'name': 'note', 'description': '笔记工具 - 创建、读取、更新、删除结构化笔记，支持任务状态、结论、阻塞项等类型', 'parameters': {'type': 'object', 'properties': {'action': {'type': 'string', 'description': '操作类型: create(创建), read(读取), update(更新), delete(删除), list(列表), search(搜索), summary(摘要)'}, 'title': {'type': 'string', 'description': '笔记标题（create/update时必需）'}, 'content': {'type': 'string', 'description': '笔记内容（create/update时必需）'}, 'note_type': {'type': 'string', 'description': '笔记类型: task_state(任务状态), conclusion(结论), blocker(阻塞项), action(行动计划), reference(参考), general(通用)', 'default': 'general'}, 'tags': {'type': 'string', 'description': '标签列表（可选）'}, 'note_id': {'type': 'string', 'description': '笔记ID（read/update/delete时必需）'}, 'query': {'type': 'string', 'description': '搜索关键词（search时必需）'}, 'limit': {'type': 'integer', 'description': '返回结果数量限制（默认10）', 'default': 10}}, 'required': ['action']}}}, {'type': 'function', 'function': {'name': 'memory', 'description': '记忆工具 - 可以存储和检索对话历史、知识和经验', 'parameters': {'type': 'object', 'properties': {'action': {'type': 'string', 'description': '要执行的操作：add(添加记忆), search(搜索记忆), summary(获取摘要), stats(获取统计), update(更新记忆), remove(删除记忆), forget(遗忘记忆), consolidate(整合记忆), clear_all(清空所有记忆)'}, 'content': {'type': 'string', 'description': '记忆内容（add/update时可用；感知记忆可作描述）'}, 'query': {'type': 'string', 'description': '搜索查询（search时可用）'}, 'memory_type': {'type': 'string', 'description': '记忆类型：working, episodic, semantic, perceptual（默认：working）', 'default': 'working'}, 'importance': {'type': 'number', 'description': '重要性分数，0.0-1.0（add/update时可用）'}, 'limit': {'type': 'integer', 'description': '搜索结果数量限制（默认：5）', 'default': 5}, 'memory_id': {'type': 'string', 'description': '目标记忆ID（update/remove时必需）'}, 'file_path': {'type': 'string', 'description': '感知记忆：本地文件路径（image/audio）'}, 'modality': {'type': 'string', 'description': '感知记忆模态：text/image/audio（不传则按扩展名推断）'}, 'strategy': {'type': 'string', 'description': '遗忘策略：importance_based/time_based/capacity_based（forget时可用）', 'default': 'importance_based'}, 'threshold': {'type': 'number', 'description': '遗忘阈值（forget时可用，默认0.1）', 'default': 0.1}, 'max_age_days': {'type': 'integer', 'description': '最大保留天数（forget策略为time_based时可用）', 'default': 30}, 'from_type': {'type': 'string', 'description': '整合来源类型（consolidate时可用，默认working）', 'default': 'working'}, 'to_type': {'type': 'string', 'description': '整合目标类型（consolidate时可用，默认episodic）', 'default': 'episodic'}, 'importance_threshold': {'type': 'number', 'description': '整合重要性阈值（默认0.7）', 'default': 0.7}}, 'required': ['action']}}}]
#
# 🤖 助手: 已创建任务状态笔记，记录了当前的任务规划与状态。接下来可以根据任务状态笔记来跟踪和管理项目进度。你可以随时更新或查询这个笔记来获取最新的任务信息或进展。
#
# ================================================================================
#
#
# 助手总结:
# 已创建任务状态笔记，记录了当前的任务规划与状态。接下来可以根据任务状态笔记来跟踪和管理项目进度。你可以随时更新或查询这个笔记来获取最新的任务信息或进展。...
#
# ### 2. 让 Agent 创建详细的重构计划 ###
# 💡 提示：Agent 会自主决定如何创建和组织重构计划
#
#
# ================================================================================
# 👤 用户: 请基于我们的分析，创建一个详细的本周重构计划。计划应该包括：目标、具体任务清单、时间安排和风险。请使用 NoteTool 创建一个 task_state 类型的笔记来记录这个计划。
# ================================================================================
#
# 🤖 Agent 正在思考并决定使用哪些工具...
#
# [{'type': 'function', 'function': {'name': 'terminal', 'description': '命令行工具 - 执行安全的文件系统、文本处理和代码执行命令（ls, cat, grep, head, tail等）', 'parameters': {'type': 'object', 'properties': {'command': {'type': 'string', 'description': "要执行的命令（白名单: cd, cut, df, dir, echo, file, head, ls, python, whereis...）\n示例: 'ls -la', 'cat file.txt', 'grep pattern *.py', 'head -n 20 data.csv'"}}, 'required': ['command']}}}, {'type': 'function', 'function': {'name': 'note', 'description': '笔记工具 - 创建、读取、更新、删除结构化笔记，支持任务状态、结论、阻塞项等类型', 'parameters': {'type': 'object', 'properties': {'action': {'type': 'string', 'description': '操作类型: create(创建), read(读取), update(更新), delete(删除), list(列表), search(搜索), summary(摘要)'}, 'title': {'type': 'string', 'description': '笔记标题（create/update时必需）'}, 'content': {'type': 'string', 'description': '笔记内容（create/update时必需）'}, 'note_type': {'type': 'string', 'description': '笔记类型: task_state(任务状态), conclusion(结论), blocker(阻塞项), action(行动计划), reference(参考), general(通用)', 'default': 'general'}, 'tags': {'type': 'string', 'description': '标签列表（可选）'}, 'note_id': {'type': 'string', 'description': '笔记ID（read/update/delete时必需）'}, 'query': {'type': 'string', 'description': '搜索关键词（search时必需）'}, 'limit': {'type': 'integer', 'description': '返回结果数量限制（默认10）', 'default': 10}}, 'required': ['action']}}}, {'type': 'function', 'function': {'name': 'memory', 'description': '记忆工具 - 可以存储和检索对话历史、知识和经验', 'parameters': {'type': 'object', 'properties': {'action': {'type': 'string', 'description': '要执行的操作：add(添加记忆), search(搜索记忆), summary(获取摘要), stats(获取统计), update(更新记忆), remove(删除记忆), forget(遗忘记忆), consolidate(整合记忆), clear_all(清空所有记忆)'}, 'content': {'type': 'string', 'description': '记忆内容（add/update时可用；感知记忆可作描述）'}, 'query': {'type': 'string', 'description': '搜索查询（search时可用）'}, 'memory_type': {'type': 'string', 'description': '记忆类型：working, episodic, semantic, perceptual（默认：working）', 'default': 'working'}, 'importance': {'type': 'number', 'description': '重要性分数，0.0-1.0（add/update时可用）'}, 'limit': {'type': 'integer', 'description': '搜索结果数量限制（默认：5）', 'default': 5}, 'memory_id': {'type': 'string', 'description': '目标记忆ID（update/remove时必需）'}, 'file_path': {'type': 'string', 'description': '感知记忆：本地文件路径（image/audio）'}, 'modality': {'type': 'string', 'description': '感知记忆模态：text/image/audio（不传则按扩展名推断）'}, 'strategy': {'type': 'string', 'description': '遗忘策略：importance_based/time_based/capacity_based（forget时可用）', 'default': 'importance_based'}, 'threshold': {'type': 'number', 'description': '遗忘阈值（forget时可用，默认0.1）', 'default': 0.1}, 'max_age_days': {'type': 'integer', 'description': '最大保留天数（forget策略为time_based时可用）', 'default': 30}, 'from_type': {'type': 'string', 'description': '整合来源类型（consolidate时可用，默认working）', 'default': 'working'}, 'to_type': {'type': 'string', 'description': '整合目标类型（consolidate时可用，默认episodic）', 'default': 'episodic'}, 'importance_threshold': {'type': 'number', 'description': '整合重要性阈值（默认0.7）', 'default': 0.7}}, 'required': ['action']}}}]
#
# 🤖 助手: 已创建本周重构计划的任务状态笔记，详细记录了目标、具体任务清单、时间安排和风险。你可以根据这个计划来跟进项目进度，并在需要时调整任务。
#
# ================================================================================
#
#
# 助手总结:
# 已创建本周重构计划的任务状态笔记，详细记录了目标、具体任务清单、时间安排和风险。你可以根据这个计划来跟进项目进度，并在需要时调整任务。...

# %%
"""一周后: 检查进度"""
print("\n" + "=" * 80)
print("一周后: 检查进度")
print("=" * 80 + "\n")

# 1. 查看笔记摘要
print("### 1. 笔记摘要 ###")
summary = maintainer.note_tool.run({"action": "summary"})
print("📊 笔记摘要:")
print(json.dumps(summary, indent=2, ensure_ascii=False))
print()

# 2. 生成完整报告
print("### 2. 会话报告 ###")
report = maintainer.generate_report()
print("\n📄 会话报告:")
print(json.dumps(report, indent=2, ensure_ascii=False))

# %%
# 额外演示
print("\n\n" + "=" * 80)
print("额外演示")
print("=" * 80)

demonstrate_cross_session_continuity()
demonstrate_tool_synergy()

print("\n" + "=" * 80)
print("完整演示结束!")
print("=" * 80)

# %%
"""主函数 - 演示 CodebaseMaintainer 的使用（Agentic 版本）

在这个版本中：
- Agent 自主决定使用哪些工具
- 不预定义工作流
- Agent 根据需求灵活探索代码库
"""
print("=" * 80)
print("CodebaseMaintainer 演示（Agentic 版本）")
print("=" * 80 + "\n")

# 初始化助手
maintainer = CodebaseMaintainer(
    project_name="Iconix",
    #实际使用的时候替换代码路径
    codebase_path="/mnt/d/studying-code/Iconix_code/Back_end_v4",
    llm=HelloAgentsLLM()
)
# Out:
# INFO:hello_agents.memory.manager:MemoryManager初始化完成，启用记忆类型: ['working']
# ================================================================================
# CodebaseMaintainer 演示（Agentic 版本）
# ================================================================================
#
# ✅ 工具 'terminal' 已注册。
# ✅ 工具 'note' 已注册。
# ✅ 工具 'memory' 已注册。
# ✅ 代码库维护助手已初始化: Iconix (Agentic Mode)
# 📁 工作目录: /mnt/d/studying-code/Iconix_code/Back_end_v4
# 🆔 会话ID: session_20251208_075554
# 🔧 可用工具: terminal, note, memory

# %%
# 探索代码库（Agent 自主决定如何探索）
print("\n### 探索代码库（Agent 自主探索）###")
response = maintainer.explore()
# Out:
# ### 探索代码库（Agent 自主探索）###
#
# ================================================================================
# 👤 用户: 请探索 . 的代码结构，了解项目组织方式
# ================================================================================
#
# 🤖 Agent 正在思考并决定使用哪些工具...
#
# [{'type': 'function', 'function': {'name': 'terminal', 'description': '命令行工具 - 执行安全的文件系统、文本处理和代码执行命令（ls, cat, grep, head, tail等）', 'parameters': {'type': 'object', 'properties': {'command': {'type': 'string', 'description': "要执行的命令（白名单: df, du, echo, file, find, less, python, sh, sort, which...）\n示例: 'ls -la', 'cat file.txt', 'grep pattern *.py', 'head -n 20 data.csv'"}}, 'required': ['command']}}}, {'type': 'function', 'function': {'name': 'note', 'description': '笔记工具 - 创建、读取、更新、删除结构化笔记，支持任务状态、结论、阻塞项等类型', 'parameters': {'type': 'object', 'properties': {'action': {'type': 'string', 'description': '操作类型: create(创建), read(读取), update(更新), delete(删除), list(列表), search(搜索), summary(摘要)'}, 'title': {'type': 'string', 'description': '笔记标题（create/update时必需）'}, 'content': {'type': 'string', 'description': '笔记内容（create/update时必需）'}, 'note_type': {'type': 'string', 'description': '笔记类型: task_state(任务状态), conclusion(结论), blocker(阻塞项), action(行动计划), reference(参考), general(通用)', 'default': 'general'}, 'note_id': {'type': 'string', 'description': '笔记ID（read/update/delete时必需）'}, 'query': {'type': 'string', 'description': '搜索关键词（search时必需）'}, 'limit': {'type': 'integer', 'description': '返回结果数量限制（默认10）', 'default': 10}}, 'required': ['action']}}}, {'type': 'function', 'function': {'name': 'memory', 'description': '记忆工具 - 可以存储和检索对话历史、知识和经验', 'parameters': {'type': 'object', 'properties': {'action': {'type': 'string', 'description': '要执行的操作：add(添加记忆), search(搜索记忆), summary(获取摘要), stats(获取统计), update(更新记忆), remove(删除记忆), forget(遗忘记忆), consolidate(整合记忆), clear_all(清空所有记忆)'}, 'content': {'type': 'string', 'description': '记忆内容（add/update时可用；感知记忆可作描述）'}, 'query': {'type': 'string', 'description': '搜索查询（search时可用）'}, 'memory_type': {'type': 'string', 'description': '记忆类型：working, episodic, semantic, perceptual（默认：working）', 'default': 'working'}, 'importance': {'type': 'number', 'description': '重要性分数，0.0-1.0（add/update时可用）'}, 'limit': {'type': 'integer', 'description': '搜索结果数量限制（默认：5）', 'default': 5}, 'memory_id': {'type': 'string', 'description': '目标记忆ID（update/remove时必需）'}, 'file_path': {'type': 'string', 'description': '感知记忆：本地文件路径（image/audio）'}, 'modality': {'type': 'string', 'description': '感知记忆模态：text/image/audio（不传则按扩展名推断）'}, 'strategy': {'type': 'string', 'description': '遗忘策略：importance_based/time_based/capacity_based（forget时可用）', 'default': 'importance_based'}, 'threshold': {'type': 'number', 'description': '遗忘阈值（forget时可用，默认0.1）', 'default': 0.1}, 'max_age_days': {'type': 'integer', 'description': '最大保留天数（forget策略为time_based时可用）', 'default': 30}, 'from_type': {'type': 'string', 'description': '整合来源类型（consolidate时可用，默认working）', 'default': 'working'}, 'to_type': {'type': 'string', 'description': '整合目标类型（consolidate时可用，默认episodic）', 'default': 'episodic'}, 'importance_threshold': {'type': 'number', 'description': '整合重要性阈值（默认0.7）', 'default': 0.7}}, 'required': ['action']}}}]
# ChatCompletion(id='chatcmpl-CkQO5qHNVr4xy4QWNhr1m9ZoexCTN', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_CCMXUWB9tLUdsrcGS0NRG06E', function=Function(arguments='{"command":"ls -R"}', name='terminal'), type='function')]))], created=1765180557, model='gpt-4o', object='chat.completion', service_tier='default', system_fingerprint='fp_a4d13246c5', usage=CompletionUsage(completion_tokens=16, prompt_tokens=1325, total_tokens=1341, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)), code=0, msg='success')
# ChatCompletion(id='chatcmpl-CkQO8tc3NsPik2Oo0Q3GXArSY3ccv', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content='1. **结论**: 这个项目是一个基于 Django 框架的应用，包含多个功能模块和数据处理功能。\n\n2. **依据**:\n   - 项目根目录包含 `manage.py` 和 `requirements.txt`，典型的 Django 项目文件。\n   - `DjangoDemo` 目录是主要的 Django 应用模块，包含 `settings.py`, `urls.py`, `views`, 以及 `utils` 和 `deepSearch` 子模块。\n   - `Loras`, `doc`, `results`, `staticfiles` 等目录，分别用于存储模型、文档、生成结果和静态文件。\n   - `results` 目录下细分为 `colored`, `filled`, `outline`, `semantic`, `visual`，可能用于不同类型的处理结果。\n   - `staticfiles` 目录中有 `admin` 和 `rest_framework` 相关文件，显示项目可能使用了 Django Admin 和 DRF。\n\n3. **风险与假设**:\n   - 假设项目结构和命名符合 Django 的标准约定。\n   - 未知具体业务功能和模块之间的依赖关系，需要进一步查看代码和文档。\n\n4. **下一步行动建议**:\n   - 查看 `settings.py` 了解项目配置。\n   - 查看 `urls.py` 和 `views` 目录了解应用的路由和视图逻辑。\n   - 研究 `deepSearch` 和 `utils` 中的 Python 文件，理解数据处理和业务逻辑。\n   - 检查 `requirements.txt` 以了解项目依赖的第三方库。\n\n我将创建一个笔记以记录这些发现和建议。', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_26dYI1ERhbeLef1EzaYImMSF', function=Function(arguments='{"action":"create","title":"Iconix Project Structure Exploration","content":"1. Conclusion: The project is a Django-based application with multiple functional modules and data processing.\\n\\n2. Evidence:\\n   - The root directory includes \'manage.py\' and \'requirements.txt\', typical for a Django project.\\n   - \'DjangoDemo\' directory is the main Django app module, containing \'settings.py\', \'urls.py\', \'views\', and submodules like \'utils\' and \'deepSearch\'.\\n   - \'Loras\', \'doc\', \'results\', \'staticfiles\' directories are for models, documentation, generated results, and static files.\\n   - \'results\' directory has subdirectories for different result types: \'colored\', \'filled\', \'outline\', \'semantic\', and \'visual\'.\\n   - \'staticfiles\' includes \'admin\' and \'rest_framework\', indicating the use of Django Admin and DRF.\\n\\n3. Risks and Assumptions:\\n   - Assumption that the project structure and naming follow Django conventions.\\n   - Unknown specific business functions and inter-module dependencies, requiring further code and document review.\\n\\n4. Next Steps Recommendations:\\n   - Review \'settings.py\' for project configuration.\\n   - Examine \'urls.py\' and the \'views\' directory for routing and view logic.\\n   - Study Python files in \'deepSearch\' and \'utils\' for data processing and business logic.\\n   - Check \'requirements.txt\' for third-party library dependencies.","note_type":"conclusion"}', name='note'), type='function')]))], created=1765180560, model='gpt-4o', object='chat.completion', service_tier='default', system_fingerprint='fp_ed643dde95', usage=CompletionUsage(completion_tokens=684, prompt_tokens=43360, total_tokens=44044, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)), code=0, msg='success')
# ChatCompletion(id='chatcmpl-CkQOJqqbGvxg7poSZuhMTrAdMk4T9', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='我已将项目结构和分析结论记录在笔记中。这些信息将有助于后续的代码库探索和开发工作。如果你需要更深入的分析或特定模块的细节，请告诉我。', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1765180571, model='gpt-4o', object='chat.completion', service_tier='default', system_fingerprint='fp_a4d13246c5', usage=CompletionUsage(completion_tokens=49, prompt_tokens=44086, total_tokens=44135, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)), code=0, msg='success')
#
# 🤖 助手: 我已将项目结构和分析结论记录在笔记中。这些信息将有助于后续的代码库探索和开发工作。如果你需要更深入的分析或特定模块的细节，请告诉我。
#
# ================================================================================

# %%
# 分析代码质量（Agent 自主决定分析方法）
print("\n### 分析代码质量（Agent 自主分析）###")
response = maintainer.analyze()
# Out:
# ### 分析代码质量（Agent 自主分析）###
#
# ================================================================================
# 👤 用户: 请分析代码质量
# ================================================================================
#
# 🤖 Agent 正在思考并决定使用哪些工具...
#
# [{'type': 'function', 'function': {'name': 'terminal', 'description': '命令行工具 - 执行安全的文件系统、文本处理和代码执行命令（ls, cat, grep, head, tail等）', 'parameters': {'type': 'object', 'properties': {'command': {'type': 'string', 'description': "要执行的命令（白名单: df, du, echo, file, find, less, python, sh, sort, which...）\n示例: 'ls -la', 'cat file.txt', 'grep pattern *.py', 'head -n 20 data.csv'"}}, 'required': ['command']}}}, {'type': 'function', 'function': {'name': 'note', 'description': '笔记工具 - 创建、读取、更新、删除结构化笔记，支持任务状态、结论、阻塞项等类型', 'parameters': {'type': 'object', 'properties': {'action': {'type': 'string', 'description': '操作类型: create(创建), read(读取), update(更新), delete(删除), list(列表), search(搜索), summary(摘要)'}, 'title': {'type': 'string', 'description': '笔记标题（create/update时必需）'}, 'content': {'type': 'string', 'description': '笔记内容（create/update时必需）'}, 'note_type': {'type': 'string', 'description': '笔记类型: task_state(任务状态), conclusion(结论), blocker(阻塞项), action(行动计划), reference(参考), general(通用)', 'default': 'general'}, 'note_id': {'type': 'string', 'description': '笔记ID（read/update/delete时必需）'}, 'query': {'type': 'string', 'description': '搜索关键词（search时必需）'}, 'limit': {'type': 'integer', 'description': '返回结果数量限制（默认10）', 'default': 10}}, 'required': ['action']}}}, {'type': 'function', 'function': {'name': 'memory', 'description': '记忆工具 - 可以存储和检索对话历史、知识和经验', 'parameters': {'type': 'object', 'properties': {'action': {'type': 'string', 'description': '要执行的操作：add(添加记忆), search(搜索记忆), summary(获取摘要), stats(获取统计), update(更新记忆), remove(删除记忆), forget(遗忘记忆), consolidate(整合记忆), clear_all(清空所有记忆)'}, 'content': {'type': 'string', 'description': '记忆内容（add/update时可用；感知记忆可作描述）'}, 'query': {'type': 'string', 'description': '搜索查询（search时可用）'}, 'memory_type': {'type': 'string', 'description': '记忆类型：working, episodic, semantic, perceptual（默认：working）', 'default': 'working'}, 'importance': {'type': 'number', 'description': '重要性分数，0.0-1.0（add/update时可用）'}, 'limit': {'type': 'integer', 'description': '搜索结果数量限制（默认：5）', 'default': 5}, 'memory_id': {'type': 'string', 'description': '目标记忆ID（update/remove时必需）'}, 'file_path': {'type': 'string', 'description': '感知记忆：本地文件路径（image/audio）'}, 'modality': {'type': 'string', 'description': '感知记忆模态：text/image/audio（不传则按扩展名推断）'}, 'strategy': {'type': 'string', 'description': '遗忘策略：importance_based/time_based/capacity_based（forget时可用）', 'default': 'importance_based'}, 'threshold': {'type': 'number', 'description': '遗忘阈值（forget时可用，默认0.1）', 'default': 0.1}, 'max_age_days': {'type': 'integer', 'description': '最大保留天数（forget策略为time_based时可用）', 'default': 30}, 'from_type': {'type': 'string', 'description': '整合来源类型（consolidate时可用，默认working）', 'default': 'working'}, 'to_type': {'type': 'string', 'description': '整合目标类型（consolidate时可用，默认episodic）', 'default': 'episodic'}, 'importance_threshold': {'type': 'number', 'description': '整合重要性阈值（默认0.7）', 'default': 0.7}}, 'required': ['action']}}}]
# ChatCompletion(id='chatcmpl-CkQWuovtVG55K3z6ANzJ15TIY7KID', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_o3BDIk9rYo8asMAVcdwqqQF7', function=Function(arguments='{"command":"find . -name \'*.py\' | xargs grep -E \'TODO|FIXME|BUG\'"}', name='terminal'), type='function')]))], created=1765181104, model='gpt-4o', object='chat.completion', service_tier='default', system_fingerprint='fp_ed643dde95', usage=CompletionUsage(completion_tokens=34, prompt_tokens=1372, total_tokens=1406, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)), code=0, msg='success')
# ChatCompletion(id='chatcmpl-CkQWwhEduOLZ2DbFXk3efoVmy0VHK', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_hh4fC5QhnZ2JvEjbN6IMvqMA', function=Function(arguments='{"command":"find . -name \'*.py\' -exec grep -EHn \'TODO|FIXME|BUG\' {} \\\\;"}', name='terminal'), type='function')]))], created=1765181106, model='gpt-4o', object='chat.completion', service_tier='default', system_fingerprint='fp_37d212baff', usage=CompletionUsage(completion_tokens=37, prompt_tokens=1528, total_tokens=1565, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)), code=0, msg='success')
# ChatCompletion(id='chatcmpl-CkQWzXeXlgQ17qx77TqMM9yMPkzyH', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_PSZuyoz5koUhO6gmpEc3AuE9', function=Function(arguments='{"action":"create","title":"Initial Code Quality Analysis","content":"No TODO, FIXME, or BUG comments were found in the Python code files, indicating no explicit pending tasks or known issues have been annotated by developers. The presence of `DEBUG = True` in the settings file suggests development mode is on, which is not suitable for production environments.","note_type":"conclusion"}', name='note'), type='function')]))], created=1765181109, model='gpt-4o', object='chat.completion', service_tier='default', system_fingerprint='fp_a4d13246c5', usage=CompletionUsage(completion_tokens=84, prompt_tokens=1585, total_tokens=1669, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)), code=0, msg='success')
# ChatCompletion(id='chatcmpl-CkQX2XFBrWg5HI1Tb6lMH5hSXeFWw', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_Qxcp4TtTNY0t9beYpx7aoui3', function=Function(arguments='{"command":"find . -name \'*.py\' | xargs pylint"}', name='terminal'), type='function')]))], created=1765181112, model='gpt-4o', object='chat.completion', service_tier='default', system_fingerprint='fp_ed643dde95', usage=CompletionUsage(completion_tokens=24, prompt_tokens=1707, total_tokens=1731, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=1280)), code=0, msg='success')
# ChatCompletion(id='chatcmpl-CkQX38IgeLoNvQX6X2siGxyFPjbES', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_HdKIxqrUjUBMhB4kdqQSGUbr', function=Function(arguments='{"command":"find . -name \'*.py\' | xargs flake8"}', name='terminal'), type='function')]))], created=1765181113, model='gpt-4o', object='chat.completion', service_tier='default', system_fingerprint='fp_83554c687e', usage=CompletionUsage(completion_tokens=26, prompt_tokens=1764, total_tokens=1790, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)), code=0, msg='success')
# ChatCompletion(id='chatcmpl-CkQX5XIZdzcXebyynGPeBFkBY1E7l', choices=[Choice(finish_reason='tool_calls', index=0, logprobs=None, message=ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_p6fStC8sVLt31Yn78oHRkE7p', function=Function(arguments='{"action":"create","title":"Code Quality Tools Unavailable","content":"Pylint and Flake8 are not available in the current environment, preventing automated code analysis for style and potential errors. This limits the ability to perform a thorough code quality assessment.","note_type":"blocker"}', name='note'), type='function')]))], created=1765181115, model='gpt-4o', object='chat.completion', service_tier='default', system_fingerprint='fp_83554c687e', usage=CompletionUsage(completion_tokens=66, prompt_tokens=1825, total_tokens=1891, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=1664)), code=0, msg='success')
# ChatCompletion(id='chatcmpl-CkQX7z1CNyd2Raq4HQflSSdejKCFb', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='1. **结论**  \n   - 项目中没有标记为TODO、FIXME或BUG的注释，表明开发者未明确记录待办任务或已知问题。\n   - `DjangoDemo/settings.py`文件中设置了`DEBUG = True`，这意味着当前配置适用于开发环境，但不适合生产环境。\n   - 自动化代码质量分析工具（如Pylint和Flake8）在当前环境中不可用，限制了对代码风格和潜在错误的深入检查。\n\n2. **依据**  \n   - 使用`grep`命令检查了代码中的TODO、FIXME和BUG标记。\n   - 发现`DEBUG = True`说明项目可能仍处于开发阶段。\n   - 试图运行Pylint和Flake8以分析代码质量，但发现这些工具在环境中不可用。\n\n3. **风险与假设**  \n   - 假设代码中没有注释标记的潜在问题，但这不一定反映代码实际质量。\n   - 生产环境未关闭DEBUG选项可能导致安全性降低和性能问题。\n\n4. **下一步行动建议**  \n   - 确保在生产环境中将`DEBUG`设置为`False`。\n   - 安装并配置Pylint和Flake8以进行详细的代码质量分析。\n   - 开发者应考虑在代码中使用TODO、FIXME标记来记录待办任务和已知问题，促进代码维护和改进。', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1765181117, model='gpt-4o', object='chat.completion', service_tier='default', system_fingerprint='fp_37d212baff', usage=CompletionUsage(completion_tokens=325, prompt_tokens=1930, total_tokens=2255, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=1536)), code=0, msg='success')
#
# 🤖 助手: 1. **结论**
#    - 项目中没有标记为TODO、FIXME或BUG的注释，表明开发者未明确记录待办任务或已知问题。
#    - `DjangoDemo/settings.py`文件中设置了`DEBUG = True`，这意味着当前配置适用于开发环境，但不适合生产环境。
#    - 自动化代码质量分析工具（如Pylint和Flake8）在当前环境中不可用，限制了对代码风格和潜在错误的深入检查。
#
# 2. **依据**
#    - 使用`grep`命令检查了代码中的TODO、FIXME和BUG标记。
#    - 发现`DEBUG = True`说明项目可能仍处于开发阶段。
#    - 试图运行Pylint和Flake8以分析代码质量，但发现这些工具在环境中不可用。
#
# 3. **风险与假设**
#    - 假设代码中没有注释标记的潜在问题，但这不一定反映代码实际质量。
#    - 生产环境未关闭DEBUG选项可能导致安全性降低和性能问题。
#
# 4. **下一步行动建议**
#    - 确保在生产环境中将`DEBUG`设置为`False`。
#    - 安装并配置Pylint和Flake8以进行详细的代码质量分析。
#    - 开发者应考虑在代码中使用TODO、FIXME标记来记录待办任务和已知问题，促进代码维护和改进。
#
# ================================================================================

# %%
# 规划下一步（Agent 基于历史信息规划）
print("\n### 规划下一步任务（Agent 自主规划）###")
response = maintainer.plan_next_steps()

# 生成报告
print("\n### 生成会话报告 ###")
report = maintainer.generate_report()
print(json.dumps(report, indent=2, ensure_ascii=False))

print("\n" + "=" * 80)
print("演示完成!")
print("=" * 80)
